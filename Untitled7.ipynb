# %% [markdown]
# <a href="https://colab.research.google.com/github/mc-juan-vargas-2024/cuadernos-y-proyectos-ia/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #cuaderno de practica de tipo datos

# %%
import pandas as pd
import numpy as np
#librerias graficas
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasificacion.csv")
df
# Out:
#      habitaciones  Area_parqeo  Are total  Valor_Miles  Clasifi
# 0             4.0         4.98        153     504000.0        2
# 1             4.0         9.14        178     453600.0        2
# 2             5.0         4.03        178     728700.0        3
# 3             4.0         2.94        187     701400.0        3
# 4             5.0         5.33        187     760200.0        2
# ..            ...          ...        ...          ...      ...
# 494           4.0         9.67        210          NaN        2
# 495           4.0         9.08        210          NaN        2
# 496           4.0         5.64        210          NaN        2
# 497           4.0         6.48        210          NaN        2
# 498           4.0         7.88        210          NaN        1
#
# [499 rows x 5 columns]

# %%
# Assuming 'habitaciones' is the column name for the number of rooms
df['habitaciones'].value_counts().plot(kind='bar')
plt.xlabel("Número de habitaciones")
plt.ylabel("Frecuencia")
plt.title("Distribución de habitaciones")
plt.xticks(rotation=0)
plt.show()

# %%
df['habitaciones'].value_counts()
# Out:
# habitaciones
# 4.0    274
# 3.0    158
# 5.0     44
# 2.0     12
# 6.0      7
# 1.0      2
# Name: count, dtype: int64

# %%
df.size,df.shape
# Out:
# (2495, (499, 5))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   habitaciones  497 non-null    float64
#  1   Area_parqeo   496 non-null    float64
#  2   Are total     499 non-null    int64
#  3   Valor_Miles   494 non-null    float64
#  4   Clasifi       499 non-null    int64
# dtypes: float64(3), int64(2)
# memory usage: 19.6 KB

# %%
# prompt: promedio habitaciones

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'habitaciones' is the column name for the number of rooms
promedio_habitaciones = df['habitaciones'].mean()
print(f"El promedio de habitaciones es: {promedio_habitaciones}")
# Out:
# El promedio de habitaciones es: 3.738430583501006

# %%
df.habitaciones.median()
# Out:
# 4.0

# %%
df.describe()
# Out:
#        habitaciones  Area_parqeo   Are total   Valor_Miles    Clasifi
# count    497.000000   496.000000  499.000000  4.940000e+02  499.00000
# mean       3.738431    12.906190  185.482966  4.537190e+05    2.02004
# std        0.726786     7.062445   21.055988  1.646495e+05    0.78105
# min        1.000000     1.980000  126.000000  1.050000e+05    1.00000
# 25%        3.000000     7.362500  174.000000  3.512250e+05    2.00000
# 50%        4.000000    11.655000  191.000000  4.368000e+05    2.00000
# 75%        4.000000    17.112500  202.000000  5.166000e+05    2.00000
# max        6.000000    37.970000  220.000000  1.024800e+06    4.00000

# %%
# prompt: dame la caja de bigotes de Area_parqeo

import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Area_parqeo' is the column name for the parking area
# If the column name is different, replace 'Area_parqeo' with the actual column name

# Check if 'Area_parqeo' column exists
if 'Area_parqeo' in df.columns:
    plt.figure(figsize=(8, 6))
    df.boxplot(column=['Area_parqeo'])
    plt.title('Boxplot of Parking Area')
    plt.ylabel('Area_parqeo')
    plt.show()

    # Calculate and print quartiles and other statistics
    area_parqeo_stats = df['Area_parqeo'].describe()
    print(area_parqeo_stats)
else:
    print("Column 'Area_parqeo' not found in the DataFrame.")
# Out:
# count    496.000000
# mean      12.906190
# std        7.062445
# min        1.980000
# 25%        7.362500
# 50%       11.655000
# 75%       17.112500
# max       37.970000
# Name: Area_parqeo, dtype: float64

# %%
# prompt: borrar todos los registros que sean superior a 32 y dejarlo en el mismo df

# Assuming 'habitaciones' is the column you want to filter
df = df[df['Area_parqeo'] <= 32]
if 'Area_parqeo' in df.columns:
    plt.figure(figsize=(8, 6))
    df.boxplot(column=['Area_parqeo'])
    plt.title('Boxplot of Parking Area')
    plt.ylabel('Area_parqeo')
    plt.show()

    # Calculate and print quartiles and other statistics
    area_parqeo_stats = df['Area_parqeo'].describe()
    print(area_parqeo_stats)
else:
    print("Column 'Area_parqeo' not found in the DataFrame.")
# Out:
# count    488.000000
# mean      12.610061
# std        6.647935
# min        1.980000
# 25%        7.250000
# 50%       11.465000
# 75%       16.910000
# max       31.990000
# Name: Area_parqeo, dtype: float64

# %%
df.shape
# Out:
# (488, 5)

# %%
df.isnull().sum()
# Out:
# habitaciones    0
# Area_parqeo     0
# Are total       0
# Valor_Miles     5
# Clasifi         0
# dtype: int64
